# %%
# This script is for sea level trend  
#import module
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import cftime

import IPython.display
import cmocean as cm
import cartopy.crs as ccrs
import cartopy.feature as cft
import sys, os, warnings
import cosima_cookbook as cc
import matplotlib.path as mpath
import cartopy.feature as cfeature
import pandas
from dask.distributed import Client
from scipy.stats import linregress

client = Client()
client
# set display num 
import pandas as pd
pd.set_option("display.max_rows", None)

# %%
#import sea level 
# EXP
aviso = xr.open_mfdataset('/g/data/p10/datalib/AVISO/MSLA_V14/comb_dt_global_allsat_phy_l4_1993_2017_sla_7d.nc')
aviso
# Out:
# <xarray.Dataset>
# Dimensions:         (latitude: 720, bnds: 2, longitude: 1440, time: 1304)
# Coordinates:
#   * latitude        (latitude) float32 -89.88 -89.62 -89.38 ... 89.62 89.88
#   * longitude       (longitude) float32 0.125 0.375 0.625 ... 359.4 359.6 359.9
#   * time            (time) datetime64[ns] 1993-01-04 1993-01-11 ... 2017-12-25
# Dimensions without coordinates: bnds
# Data variables:
#     latitude_bnds   (latitude, bnds) float32 dask.array<chunksize=(720, 2), meta=np.ndarray>
#     longitude_bnds  (longitude, bnds) float32 dask.array<chunksize=(1440, 2), meta=np.ndarray>
#     sla             (time, latitude, longitude) float64 dask.array<chunksize=(1304, 720, 1440), meta=np.ndarray>
# Attributes: (12/47)
#     CDI:                             Climate Data Interface version 1.7.0 (ht...
#     Conventions:                     CF-1.6
#     history:                         aviso and cmems duacs grids merged and m...
# ...

# %%
import ctypes

def trim_memory() -> int:
    libc = ctypes.CDLL("libc.so.6")
    return libc.malloc_trim(0)

client.run(trim_memory)
# Out:
# {'tcp://10.0.128.136:35561': 1,
#  'tcp://10.0.128.136:36807': 1,
#  'tcp://10.0.128.136:40379': 1,
#  'tcp://10.0.128.136:44695': 1}

# %%
transect_lat = [-90, -30] 
sla = aviso.sla.load().sel(latitude=slice(transect_lat[0],transect_lat[1]))
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 7.99 GiB -- Worker memory limit: 11.23 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.22 GiB -- Worker memory limit: 11.23 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.43 GiB -- Worker memory limit: 11.23 GiB
# ...
